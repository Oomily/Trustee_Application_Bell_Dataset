# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#set a random seed for replication
seed = 62583
np.random.seed(seed)
#read in training data
df = pd.read_csv('final_dataset.csv')

# %%
print(df['GlobalClass'].unique())
# Out:
# ['Benign' 'Light Attack' 'Light Benign' 'Heavy Attack' 'Heavy Benign']

# %%
df['GlobalClass'].value_counts()
# Out:
# Benign          83183
# Heavy Benign    68057
# Light Benign    24403
# Heavy Attack     5764
# Light Attack     2462
# Name: GlobalClass, dtype: int64

# %%
df['GlobalClass'] = df['GlobalClass'].map({'Benign':0,'Light Benign':0,'Heavy Benign':0, 'Light Attack':1, 'Heavy Attack':1})

# %% [markdown]
# Undersampling Benign to balance out the categories more

# %%
c0 = df[df['GlobalClass'] == 0]
c1 = df[df['GlobalClass'] == 1]
df_0 = c0.sample(8226)
undersampled_df = pd.concat([df_0, c1],axis=0)
df = undersampled_df

# %%
df['GlobalClass'].value_counts()
# Out:
# 0    8226
# 1    8226
# Name: GlobalClass, dtype: int64

# %%
feature_names = list(df.columns)
print(feature_names)
feature_names.remove('GlobalClass')
target_names = ['0', '1']
# Out:
# ['A_frequency', 'PTR_frequency', 'TXT_frequency', 'rr_count', 'rr_name_entropy', 'rr_name_length', 'distinct_ns', 'ttl_mean', 'ttl_variance', 'FQDN_count', 'subdomain_length', 'upper', 'lower', 'numeric', 'entropy', 'special', 'labels', 'labels_max', 'labels_average', 'longest_word', 'sld', 'len', 'subdomain', 'GlobalClass']

# %%
from sklearn.model_selection import train_test_split

#create feature and targets
features = df.drop('GlobalClass', axis=1)
target = df['GlobalClass']
#split data into 80% training and 20% test sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=seed)

# %%
#size for the sets
print('size of X_train:', X_train.shape)
print('size of X_test:', X_test.shape)
print('size of y_train:', y_train.shape)
print('size of y_test:', y_test.shape)
# Out:
# size of X_train: (13161, 23)
# size of X_test: (3291, 23)
# size of y_train: (13161,)
# size of y_test: (3291,)

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
hgb_classifier = HistGradientBoostingClassifier(class_weight='balanced')
hgb_classifier.fit(X_train,y_train)
y_pred_hgb = hgb_classifier.predict(X_test)
hgb_classifier.score(X_train, y_train)
# Out:
# 0.9857153711724033

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score
cm_hgb = confusion_matrix(y_test, y_pred_hgb)

from mlxtend.plotting import plot_confusion_matrix
fig, ax = plot_confusion_matrix(conf_mat=cm_hgb, figsize=(6, 6), cmap=plt.cm.Greens)
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report
accuracy_score(y_test, y_pred_hgb)
# Out:
# 0.9802491643877241

# %%
roc_auc_score(y_test, y_pred_hgb)
# Out:
# 0.980280697555365

# %%
acc_hgb = cross_val_score(estimator = hgb_classifier, X = X_train, y = y_train, cv = 10)
print("Accuracy of hgb: {:.2f} %".format(acc_hgb.mean()*100))
print("SD of hgb: {:.2f} %".format(acc_hgb.std()*100))
print(classification_report(y_test, y_pred_hgb))
# Out:
# Accuracy of hgb: 98.21 %
# SD of hgb: 0.36 %
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1662
#            1       0.98      0.98      0.98      1629
#
#     accuracy                           0.98      3291
#    macro avg       0.98      0.98      0.98      3291
# weighted avg       0.98      0.98      0.98      3291

# %%
from sklearn.model_selection import GridSearchCV
parameters_hgb = [{'max_iter': [1000,1200,1500],
                'learning_rate': [0.1],
                'max_depth' : [25, 50, 75],
                'l2_regularization': [1.5],
                'scoring': ['f1_micro']}]
grid_search_hgb = GridSearchCV(estimator = hgb_classifier,
                           param_grid = parameters_hgb,
                           scoring = 'accuracy',
                           cv = 10,
                           n_jobs = -1)
grid_search_hgb.fit(X_train, y_train)
best_accuracy_hgb = grid_search_hgb.best_score_
best_paramaeter_hgb = grid_search_hgb.best_params_  
print("Best Accuracy of HGB: {:.2f} %".format(best_accuracy_hgb.mean()*100))
print("Best Parameter of HGB:", best_paramaeter_hgb)
# Out:
# Best Accuracy of HGB: 97.69 %
# Best Parameter of HGB: {'l2_regularization': 1.5, 'learning_rate': 0.1, 'max_depth': 25, 'max_iter': 1000, 'scoring': 'f1_micro'}

# %%
from trustee import ClassificationTrustee
from sklearn import tree

trustee = ClassificationTrustee(expert=hgb_classifier)
trustee.fit(X_train, y_train, num_iter=50, num_stability_iter=10, samples_size=0.3, verbose=True)

# Get the best explanation from Trustee
dt, pruned_dt, agreement, reward = trustee.explain()
print(f"Model explanation training (agreement, fidelity): ({agreement}, {reward})")
print(f"Model Explanation size: {dt.tree_.node_count}")
print(f"Top-k Prunned Model explanation size: {pruned_dt.tree_.node_count}")

# Use explanations to make predictions
dt_y_pred = dt.predict(X_test)
pruned_dt_y_pred = pruned_dt.predict(X_test)

# Evaluate accuracy and fidelity of explanations
print("Model explanation global fidelity report:")
print(classification_report(y_pred_hgb, dt_y_pred))
print("Top-k Model explanation global fidelity report:")
print(classification_report(y_pred_hgb, pruned_dt_y_pred))

print("Model explanation score report:")
print(classification_report(y_test, dt_y_pred))
print("Top-k Model explanation score report:")
print(classification_report(y_test, pruned_dt_y_pred))

# Output decision tree to pdf
dot_data = tree.export_graphviz(
    dt,
    class_names=target_names,
    feature_names=feature_names,
    filled=True,
    rounded=True,
    special_characters=True,
)
# Out:
# Initializing training dataset using HistGradientBoostingClassifier(class_weight='balanced') as expert model
# Expert model score: 0.9859943435839448
# Initializing Trustee outer-loop with 10 iterations
# ########## Outer-loop Iteration 0/10 ##########
# Initializing Trustee inner-loop with 10 iterations
# ########## Inner-loop Iteration 0/50 ##########
# Sampling 2763 points from training dataset with (9212, 9212) entries
# Student model 0-0 trained with depth 9 and 35 leaves:
# Student model score: 0.9879279814536516
# Student model 0-0 fidelity: 0.9879279814536516
# ########## Inner-loop Iteration 1/50 ##########
# Sampling 2763 points from training dataset with (10041, 10041) entries
# Student model 0-1 trained with depth 11 and 37 leaves:
# Student model score: 0.9915553052561422
# Student model 0-1 fidelity: 0.9915553052561422
# ########## Inner-loop Iteration 2/50 ##########
# Sampling 2763 points from training dataset with (10870, 10870) entries
# Student model 0-2 trained with depth 11 and 45 leaves:
# Student model score: 0.9831092094539526
# Student model 0-2 fidelity: 0.9831092094539526
# ########## Inner-loop Iteration 3/50 ##########
# Sampling 2763 points from training dataset with (11699, 11699) entries
# Student model 0-3 trained with depth 11 and 50 leaves:
# Student model score: 0.968623717523204
# Student model 0-3 fidelity: 0.968623717523204
# ########## Inner-loop Iteration 4/50 ##########
# Sampling 2763 points from training dataset with (12528, 12528) entries
# Student model 0-4 trained with depth 11 and 49 leaves:
# Student model score: 0.9927577169481654
# Student model 0-4 fidelity: 0.9927577169481654
# ########## Inner-loop Iteration 5/50 ##########
# Sampling 2763 points from training dataset with (13357, 13357) entries
# Student model 0-5 trained with depth 8 and 25 leaves:
# Student model score: 0.986727215830113
# Student model 0-5 fidelity: 0.986727215830113
# ########## Inner-loop Iteration 6/50 ##########
# Sampling 2763 points from training dataset with (14186, 14186) entries
# Student model 0-6 trained with depth 10 and 50 leaves:
# Student model score: 0.9879333232413801
# Student model 0-6 fidelity: 0.9879333232413801
# ########## Inner-loop Iteration 7/50 ##########
# Sampling 2763 points from training dataset with (15015, 15015) entries
# Student model 0-7 trained with depth 12 and 43 leaves:
# Student model score: 0.9903481196879731
# Student model 0-7 fidelity: 0.9903481196879731
# ########## Inner-loop Iteration 8/50 ##########
# Sampling 2763 points from training dataset with (15844, 15844) entries
# Student model 0-8 trained with depth 12 and 46 leaves:
# Student model score: 0.9855247075257552
# Student model 0-8 fidelity: 0.9855247075257552
# ########## Inner-loop Iteration 9/50 ##########
# Sampling 2763 points from training dataset with (16673, 16673) entries
# Student model 0-9 trained with depth 10 and 44 leaves:
# Student model score: 0.9829152682093858
# Student model 0-9 fidelity: 0.9829152682093858
# ########## Inner-loop Iteration 10/50 ##########
# Sampling 2763 points from training dataset with (17502, 17502) entries
# Student model 0-10 trained with depth 12 and 42 leaves:
# Student model score: 0.9891230346456349
# Student model 0-10 fidelity: 0.9891230346456349
# ########## Inner-loop Iteration 11/50 ##########
# Sampling 2763 points from training dataset with (18331, 18331) entries
# Student model 0-11 trained with depth 10 and 41 leaves:
# Student model score: 0.9927621009988126
# Student model 0-11 fidelity: 0.9927621009988126
# ########## Inner-loop Iteration 12/50 ##########
# Sampling 2763 points from training dataset with (19160, 19160) entries
# Student model 0-12 trained with depth 11 and 43 leaves:
# Student model score: 0.989135895229317
# Student model 0-12 fidelity: 0.989135895229317
# ########## Inner-loop Iteration 13/50 ##########
# Sampling 2763 points from training dataset with (19989, 19989) entries
# Student model 0-13 trained with depth 12 and 46 leaves:
# Student model score: 0.9891273460144532
# Student model 0-13 fidelity: 0.9891273460144532
# ########## Inner-loop Iteration 14/50 ##########
# Sampling 2763 points from training dataset with (20818, 20818) entries
# Student model 0-14 trained with depth 11 and 43 leaves:
# Student model score: 0.9831080294350518
# Student model 0-14 fidelity: 0.9831080294350518
# ########## Inner-loop Iteration 15/50 ##########
# Sampling 2763 points from training dataset with (21647, 21647) entries
# Student model 0-15 trained with depth 10 and 43 leaves:
# Student model score: 0.9794789132109321
# Student model 0-15 fidelity: 0.9794789132109321
# ########## Inner-loop Iteration 16/50 ##########
# Sampling 2763 points from training dataset with (22476, 22476) entries
# Student model 0-16 trained with depth 10 and 38 leaves:
# Student model score: 0.9831050786663406
# Student model 0-16 fidelity: 0.9831050786663406
# ########## Inner-loop Iteration 17/50 ##########
# Sampling 2763 points from training dataset with (23305, 23305) entries
# Student model 0-17 trained with depth 11 and 39 leaves:
# Student model score: 0.9758449883449883
# Student model 0-17 fidelity: 0.9758449883449883
# ########## Inner-loop Iteration 18/50 ##########
# Sampling 2763 points from training dataset with (24134, 24134) entries
# Student model 0-18 trained with depth 9 and 40 leaves:
# Student model score: 0.98672327365431
# Student model 0-18 fidelity: 0.98672327365431
# ########## Inner-loop Iteration 19/50 ##########
# Sampling 2763 points from training dataset with (24963, 24963) entries
# Student model 0-19 trained with depth 11 and 41 leaves:
# Student model score: 0.9866863667753385
# Student model 0-19 fidelity: 0.9866863667753385
# ########## Inner-loop Iteration 20/50 ##########
# Sampling 2763 points from training dataset with (25792, 25792) entries
# Student model 0-20 trained with depth 9 and 46 leaves:
# Student model score: 0.9915276879479427
# Student model 0-20 fidelity: 0.9915276879479427
# ########## Inner-loop Iteration 21/50 ##########
# Sampling 2763 points from training dataset with (26621, 26621) entries
# Student model 0-21 trained with depth 10 and 45 leaves:
# Student model score: 0.9867158467318419
# Student model 0-21 fidelity: 0.9867158467318419
# ########## Inner-loop Iteration 22/50 ##########
# Sampling 2763 points from training dataset with (27450, 27450) entries
# Student model 0-22 trained with depth 12 and 33 leaves:
# Student model score: 0.9867216497247207
# Student model 0-22 fidelity: 0.9867216497247207
# ########## Inner-loop Iteration 23/50 ##########
# Sampling 2763 points from training dataset with (28279, 28279) entries
# Student model 0-23 trained with depth 12 and 37 leaves:
# Student model score: 0.9903496926802011
# Student model 0-23 fidelity: 0.9903496926802011
# ########## Inner-loop Iteration 24/50 ##########
# Sampling 2763 points from training dataset with (29108, 29108) entries
# Student model 0-24 trained with depth 11 and 47 leaves:
# Student model score: 0.9915418643462545
# Student model 0-24 fidelity: 0.9915418643462545
# ########## Inner-loop Iteration 25/50 ##########
# Sampling 2763 points from training dataset with (29937, 29937) entries
# Student model 0-25 trained with depth 12 and 38 leaves:
# Student model score: 0.9878579630671166
# Student model 0-25 fidelity: 0.9878579630671166
# ########## Inner-loop Iteration 26/50 ##########
# Sampling 2763 points from training dataset with (30766, 30766) entries
# Student model 0-26 trained with depth 10 and 41 leaves:
# Student model score: 0.9891429777140737
# Student model 0-26 fidelity: 0.9891429777140737
# ########## Inner-loop Iteration 27/50 ##########
# Sampling 2763 points from training dataset with (31595, 31595) entries
# Student model 0-27 trained with depth 12 and 45 leaves:
# Student model score: 0.9818678121951541
# Student model 0-27 fidelity: 0.9818678121951541
# ########## Inner-loop Iteration 28/50 ##########
# Sampling 2763 points from training dataset with (32424, 32424) entries
# Student model 0-28 trained with depth 9 and 36 leaves:
# Student model score: 0.9867158467318419
# Student model 0-28 fidelity: 0.9867158467318419
# ########## Inner-loop Iteration 29/50 ##########
# Sampling 2763 points from training dataset with (33253, 33253) entries
# Student model 0-29 trained with depth 10 and 48 leaves:
# Student model score: 0.9843093234096392
# Student model 0-29 fidelity: 0.9843093234096392
# ########## Inner-loop Iteration 30/50 ##########
# Sampling 2763 points from training dataset with (34082, 34082) entries
# Student model 0-30 trained with depth 12 and 41 leaves:
# Student model score: 0.9842741553031134
# Student model 0-30 fidelity: 0.9842741553031134
# ########## Inner-loop Iteration 31/50 ##########
# Sampling 2763 points from training dataset with (34911, 34911) entries
# Student model 0-31 trained with depth 12 and 45 leaves:
# Student model score: 0.9891435464414957
# Student model 0-31 fidelity: 0.9891435464414957
# ########## Inner-loop Iteration 32/50 ##########
# Sampling 2763 points from training dataset with (35740, 35740) entries
# Student model 0-32 trained with depth 12 and 42 leaves:
# Student model score: 0.9915343622032541
# Student model 0-32 fidelity: 0.9915343622032541
# ########## Inner-loop Iteration 33/50 ##########
# Sampling 2763 points from training dataset with (36569, 36569) entries
# Student model 0-33 trained with depth 9 and 40 leaves:
# Student model score: 0.9903395716316685
# Student model 0-33 fidelity: 0.9903395716316685
# ########## Inner-loop Iteration 34/50 ##########
# Sampling 2763 points from training dataset with (37398, 37398) entries
# Student model 0-34 trained with depth 13 and 47 leaves:
# Student model score: 0.980679143263337
# Student model 0-34 fidelity: 0.980679143263337
# ########## Inner-loop Iteration 35/50 ##########
# Sampling 2763 points from training dataset with (38227, 38227) entries
# Student model 0-35 trained with depth 11 and 50 leaves:
# Student model score: 0.9915548628301907
# Student model 0-35 fidelity: 0.9915548628301907
# ########## Inner-loop Iteration 36/50 ##########
# Sampling 2763 points from training dataset with (39056, 39056) entries
# Student model 0-36 trained with depth 9 and 50 leaves:
# Student model score: 0.9830077187064431
# Student model 0-36 fidelity: 0.9830077187064431
# ########## Inner-loop Iteration 37/50 ##########
# Sampling 2763 points from training dataset with (39885, 39885) entries
# Student model 0-37 trained with depth 12 and 35 leaves:
# Student model score: 0.9903457592379088
# Student model 0-37 fidelity: 0.9903457592379088
# ########## Inner-loop Iteration 38/50 ##########
# Sampling 2763 points from training dataset with (40714, 40714) entries
# Student model 0-38 trained with depth 11 and 48 leaves:
# Student model score: 0.992740975108579
# Student model 0-38 fidelity: 0.992740975108579
# ########## Inner-loop Iteration 39/50 ##########
# Sampling 2763 points from training dataset with (41543, 41543) entries
# Student model 0-39 trained with depth 10 and 43 leaves:
# Student model score: 0.983103307710226
# Student model 0-39 fidelity: 0.983103307710226
# ########## Inner-loop Iteration 40/50 ##########
# Sampling 2763 points from training dataset with (42372, 42372) entries
# Student model 0-40 trained with depth 12 and 42 leaves:
# Student model score: 0.9927599939448282
# Student model 0-40 fidelity: 0.9927599939448282
# ########## Inner-loop Iteration 41/50 ##########
# Sampling 2763 points from training dataset with (43201, 43201) entries
# Student model 0-41 trained with depth 10 and 35 leaves:
# Student model score: 0.9867247425817092
# Student model 0-41 fidelity: 0.9867247425817092
# ########## Inner-loop Iteration 42/50 ##########
# Sampling 2763 points from training dataset with (44030, 44030) entries
# Student model 0-42 trained with depth 10 and 34 leaves:
# Student model score: 0.9746255930387635
# Student model 0-42 fidelity: 0.9746255930387635
# ########## Inner-loop Iteration 43/50 ##########
# Sampling 2763 points from training dataset with (44859, 44859) entries
# Student model 0-43 trained with depth 8 and 25 leaves:
# Student model score: 0.9867030622764462
# Student model 0-43 fidelity: 0.9867030622764462
# ########## Inner-loop Iteration 44/50 ##########
# Sampling 2763 points from training dataset with (45688, 45688) entries
# Student model 0-44 trained with depth 13 and 39 leaves:
# Student model score: 0.991540138057716
# Student model 0-44 fidelity: 0.991540138057716
# ########## Inner-loop Iteration 45/50 ##########
# Sampling 2763 points from training dataset with (46517, 46517) entries
# Student model 0-45 trained with depth 10 and 47 leaves:
# Student model score: 0.9891100164203612
# Student model 0-45 fidelity: 0.9891100164203612
# ########## Inner-loop Iteration 46/50 ##########
# Sampling 2763 points from training dataset with (47346, 47346) entries
# Student model 0-46 trained with depth 12 and 44 leaves:
# Student model score: 0.9866185350678318
# Student model 0-46 fidelity: 0.9866185350678318
# ########## Inner-loop Iteration 47/50 ##########
# Sampling 2763 points from training dataset with (48175, 48175) entries
# Student model 0-47 trained with depth 11 and 43 leaves:
# Student model score: 0.9903494679984168
# Student model 0-47 fidelity: 0.9903494679984168
# ########## Inner-loop Iteration 48/50 ##########
# Sampling 2763 points from training dataset with (49004, 49004) entries
# Student model 0-48 trained with depth 10 and 32 leaves:
# Student model score: 0.987887766790565
# Student model 0-48 fidelity: 0.987887766790565
# ########## Inner-loop Iteration 49/50 ##########
# Sampling 2763 points from training dataset with (49833, 49833) entries
# Student model 0-49 trained with depth 11 and 35 leaves:
# Student model score: 0.9891434832525025
# Student model 0-49 fidelity: 0.9891434832525025
# ########## Outer-loop Iteration 1/10 ##########
# Initializing Trustee inner-loop with 10 iterations
# ########## Inner-loop Iteration 0/50 ##########
# Sampling 2763 points from training dataset with (50662, 50662) entries
# Student model 1-0 trained with depth 12 and 43 leaves:
# Student model score: 0.9891344396466981
# Student model 1-0 fidelity: 0.9891344396466981
# ########## Inner-loop Iteration 1/50 ##########
# Sampling 2763 points from training dataset with (51491, 51491) entries
# Student model 1-1 trained with depth 9 and 37 leaves:
# Student model score: 0.9879262935905951
# Student model 1-1 fidelity: 0.9879262935905951
# ########## Inner-loop Iteration 2/50 ##########
# Sampling 2763 points from training dataset with (52320, 52320) entries
# Student model 1-2 trained with depth 13 and 42 leaves:
# Student model score: 0.9890937794636788
# Student model 1-2 fidelity: 0.9890937794636788
# ########## Inner-loop Iteration 3/50 ##########
# Sampling 2763 points from training dataset with (53149, 53149) entries
# Student model 1-3 trained with depth 12 and 49 leaves:
# Student model score: 0.9843151694738881
# Student model 1-3 fidelity: 0.9843151694738881
# ########## Inner-loop Iteration 4/50 ##########
# Sampling 2763 points from training dataset with (53978, 53978) entries
# Student model 1-4 trained with depth 12 and 49 leaves:
# Student model score: 0.9915558950853067
# Student model 1-4 fidelity: 0.9915558950853067
# ########## Inner-loop Iteration 5/50 ##########
# Sampling 2763 points from training dataset with (54807, 54807) entries
# Student model 1-5 trained with depth 12 and 58 leaves:
# Student model score: 0.9855093574475027
# Student model 1-5 fidelity: 0.9855093574475027
# ########## Inner-loop Iteration 6/50 ##########
# Sampling 2763 points from training dataset with (55636, 55636) entries
# Student model 1-6 trained with depth 11 and 38 leaves:
# Student model score: 0.9879321990473862
# Student model 1-6 fidelity: 0.9879321990473862
# ########## Inner-loop Iteration 7/50 ##########
# Sampling 2763 points from training dataset with (56465, 56465) entries
# Student model 1-7 trained with depth 11 and 42 leaves:
# Student model score: 0.9866863667753385
# Student model 1-7 fidelity: 0.9866863667753385
# ########## Inner-loop Iteration 8/50 ##########
# Sampling 2763 points from training dataset with (57294, 57294) entries
# Student model 1-8 trained with depth 11 and 45 leaves:
# Student model score: 0.9867310012062726
# Student model 1-8 fidelity: 0.9867310012062726
# ########## Inner-loop Iteration 9/50 ##########
# Sampling 2763 points from training dataset with (58123, 58123) entries
# Student model 1-9 trained with depth 10 and 41 leaves:
# Student model score: 0.9879321990473862
# Student model 1-9 fidelity: 0.9879321990473862
# ########## Inner-loop Iteration 10/50 ##########
# Sampling 2763 points from training dataset with (58952, 58952) entries
# Student model 1-10 trained with depth 12 and 49 leaves:
# Student model score: 0.9830820272413472
# Student model 1-10 fidelity: 0.9830820272413472
# ########## Inner-loop Iteration 11/50 ##########
# Sampling 2763 points from training dataset with (59781, 59781) entries
# Student model 1-11 trained with depth 10 and 45 leaves:
# Student model score: 0.9879309340787328
# Student model 1-11 fidelity: 0.9879309340787328
# ########## Inner-loop Iteration 12/50 ##########
# Sampling 2763 points from training dataset with (60610, 60610) entries
# Student model 1-12 trained with depth 10 and 39 leaves:
# Student model score: 0.9806872451951076
# Student model 1-12 fidelity: 0.9806872451951076
# ########## Inner-loop Iteration 13/50 ##########
# Sampling 2763 points from training dataset with (61439, 61439) entries
# Student model 1-13 trained with depth 11 and 39 leaves:
# Student model score: 0.9841635109776832
# Student model 1-13 fidelity: 0.9841635109776832
# ########## Inner-loop Iteration 14/50 ##########
# Sampling 2763 points from training dataset with (62268, 62268) entries
# Student model 1-14 trained with depth 12 and 51 leaves:
# Student model score: 0.9830622752533509
# Student model 1-14 fidelity: 0.9830622752533509
# ########## Inner-loop Iteration 15/50 ##########
# Sampling 2763 points from training dataset with (63097, 63097) entries
# Student model 1-15 trained with depth 11 and 50 leaves:
# Student model score: 0.9927088830255056
# Student model 1-15 fidelity: 0.9927088830255056
# ########## Inner-loop Iteration 16/50 ##########
# Sampling 2763 points from training dataset with (63926, 63926) entries
# Student model 1-16 trained with depth 12 and 44 leaves:
# Student model score: 0.9819058054208374
# Student model 1-16 fidelity: 0.9819058054208374
# ########## Inner-loop Iteration 17/50 ##########
# Sampling 2763 points from training dataset with (64755, 64755) entries
# Student model 1-17 trained with depth 11 and 41 leaves:
# Student model score: 0.985513577744382
# Student model 1-17 fidelity: 0.985513577744382
# ########## Inner-loop Iteration 18/50 ##########
# Sampling 2763 points from training dataset with (65584, 65584) entries
# Student model 1-18 trained with depth 10 and 37 leaves:
# Student model score: 0.9879224941724942
# Student model 1-18 fidelity: 0.9879224941724942
# ########## Inner-loop Iteration 19/50 ##########
# Sampling 2763 points from training dataset with (66413, 66413) entries
# Student model 1-19 trained with depth 9 and 40 leaves:
# Student model score: 0.9927255177255178
# Student model 1-19 fidelity: 0.9927255177255178
# ########## Inner-loop Iteration 20/50 ##########
# Sampling 2763 points from training dataset with (67242, 67242) entries
# Student model 1-20 trained with depth 8 and 36 leaves:
# Student model score: 0.9891293103573879
# Student model 1-20 fidelity: 0.9891293103573879
# ########## Inner-loop Iteration 21/50 ##########
# Sampling 2763 points from training dataset with (68071, 68071) entries
# Student model 1-21 trained with depth 11 and 45 leaves:
# Student model score: 0.9855171208944794
# Student model 1-21 fidelity: 0.9855171208944794
# ########## Inner-loop Iteration 22/50 ##########
# Sampling 2763 points from training dataset with (68900, 68900) entries
# Student model 1-22 trained with depth 8 and 35 leaves:
# Student model score: 0.9891273460144532
# Student model 1-22 fidelity: 0.9891273460144532
# ########## Inner-loop Iteration 23/50 ##########
# Sampling 2763 points from training dataset with (69729, 69729) entries
# Student model 1-23 trained with depth 10 and 42 leaves:
# Student model score: 0.9878716058052435
# Student model 1-23 fidelity: 0.9878716058052435
# ########## Inner-loop Iteration 24/50 ##########
# Sampling 2763 points from training dataset with (70558, 70558) entries
# Student model 1-24 trained with depth 8 and 36 leaves:
# Student model score: 0.9927463104474129
# Student model 1-24 fidelity: 0.9927463104474129
# ########## Inner-loop Iteration 25/50 ##########
# Sampling 2763 points from training dataset with (71387, 71387) entries
# Student model 1-25 trained with depth 11 and 36 leaves:
# Student model score: 0.985455970245266
# Student model 1-25 fidelity: 0.985455970245266
# ########## Inner-loop Iteration 26/50 ##########
# Sampling 2763 points from training dataset with (72216, 72216) entries
# Student model 1-26 trained with depth 9 and 38 leaves:
# Student model score: 0.9867247425817092
# Student model 1-26 fidelity: 0.9867247425817092
# ########## Inner-loop Iteration 27/50 ##########
# Sampling 2763 points from training dataset with (73045, 73045) entries
# Student model 1-27 trained with depth 9 and 34 leaves:
# Student model score: 0.9879181289277011
# Student model 1-27 fidelity: 0.9879181289277011
# ########## Inner-loop Iteration 28/50 ##########
# Sampling 2763 points from training dataset with (73874, 73874) entries
# Student model 1-28 trained with depth 10 and 43 leaves:
# Student model score: 0.9831080294350519
# Student model 1-28 fidelity: 0.9831080294350519
# ########## Inner-loop Iteration 29/50 ##########
# Sampling 2763 points from training dataset with (74703, 74703) entries
# Student model 1-29 trained with depth 11 and 45 leaves:
# Student model score: 0.9854988804925833
# Student model 1-29 fidelity: 0.9854988804925833
# ########## Inner-loop Iteration 30/50 ##########
# Sampling 2763 points from training dataset with (75532, 75532) entries
# Student model 1-30 trained with depth 11 and 52 leaves:
# Student model score: 0.9903131572797383
# Student model 1-30 fidelity: 0.9903131572797383
# ########## Inner-loop Iteration 31/50 ##########
# Sampling 2763 points from training dataset with (76361, 76361) entries
# Student model 1-31 trained with depth 12 and 48 leaves:
# Student model score: 0.9891293103573879
# Student model 1-31 fidelity: 0.9891293103573879
# ########## Inner-loop Iteration 32/50 ##########
# Sampling 2763 points from training dataset with (77190, 77190) entries
# Student model 1-32 trained with depth 9 and 35 leaves:
# Student model score: 0.9855017547132414
# Student model 1-32 fidelity: 0.9855017547132414
# ########## Inner-loop Iteration 33/50 ##########
# Sampling 2763 points from training dataset with (78019, 78019) entries
# Student model 1-33 trained with depth 10 and 43 leaves:
# Student model score: 0.9842657061890364
# Student model 1-33 fidelity: 0.9842657061890364
# ########## Inner-loop Iteration 34/50 ##########
# Sampling 2763 points from training dataset with (78848, 78848) entries
# Student model 1-34 trained with depth 11 and 51 leaves:
# Student model score: 0.9866785871326166
# Student model 1-34 fidelity: 0.9866785871326166
# ########## Inner-loop Iteration 35/50 ##########
# Sampling 2763 points from training dataset with (79677, 79677) entries
# Student model 1-35 trained with depth 11 and 41 leaves:
# Student model score: 0.9915252628366054
# Student model 1-35 fidelity: 0.9915252628366054
# ########## Inner-loop Iteration 36/50 ##########
# Sampling 2763 points from training dataset with (80506, 80506) entries
# Student model 1-36 trained with depth 10 and 50 leaves:
# Student model score: 0.9939324740721223
# Student model 1-36 fidelity: 0.9939324740721223
# ########## Inner-loop Iteration 37/50 ##########
# Sampling 2763 points from training dataset with (81335, 81335) entries
# Student model 1-37 trained with depth 11 and 45 leaves:
# Student model score: 0.9842950553542101
# Student model 1-37 fidelity: 0.9842950553542101
# ########## Inner-loop Iteration 38/50 ##########
# Sampling 2763 points from training dataset with (82164, 82164) entries
# Student model 1-38 trained with depth 7 and 33 leaves:
# Student model score: 0.9903481196879731
# Student model 1-38 fidelity: 0.9903481196879731
# ########## Inner-loop Iteration 39/50 ##########
# Sampling 2763 points from training dataset with (82993, 82993) entries
# Student model 1-39 trained with depth 14 and 52 leaves:
# Student model score: 0.980696239375946
# Student model 1-39 fidelity: 0.980696239375946
# ########## Inner-loop Iteration 40/50 ##########
# Sampling 2763 points from training dataset with (83822, 83822) entries
# Student model 1-40 trained with depth 12 and 41 leaves:
# Student model score: 0.9951723736314931
# Student model 1-40 fidelity: 0.9951723736314931
# ########## Inner-loop Iteration 41/50 ##########
# Sampling 2763 points from training dataset with (84651, 84651) entries
# Student model 1-41 trained with depth 12 and 44 leaves:
# Student model score: 0.9817182090166646
# Student model 1-41 fidelity: 0.9817182090166646
# ########## Inner-loop Iteration 42/50 ##########
# Sampling 2763 points from training dataset with (85480, 85480) entries
# Student model 1-42 trained with depth 10 and 43 leaves:
# Student model score: 0.987887766790565
# Student model 1-42 fidelity: 0.987887766790565
# ########## Inner-loop Iteration 43/50 ##########
# Sampling 2763 points from training dataset with (86309, 86309) entries
# Student model 1-43 trained with depth 12 and 50 leaves:
# Student model score: 0.9855171208944793
# Student model 1-43 fidelity: 0.9855171208944793
# ########## Inner-loop Iteration 44/50 ##########
# Sampling 2763 points from training dataset with (87138, 87138) entries
# Student model 1-44 trained with depth 10 and 38 leaves:
# Student model score: 0.9927546787237514
# Student model 1-44 fidelity: 0.9927546787237514
# ########## Inner-loop Iteration 45/50 ##########
# Sampling 2763 points from training dataset with (87967, 87967) entries
# Student model 1-45 trained with depth 13 and 47 leaves:
# Student model score: 0.9903213001447719
# Student model 1-45 fidelity: 0.9903213001447719
# ########## Inner-loop Iteration 46/50 ##########
# Sampling 2763 points from training dataset with (88796, 88796) entries
# Student model 1-46 trained with depth 9 and 42 leaves:
# Student model score: 0.9854819502171579
# Student model 1-46 fidelity: 0.9854819502171579
# ########## Inner-loop Iteration 47/50 ##########
# Sampling 2763 points from training dataset with (89625, 89625) entries
# Student model 1-47 trained with depth 12 and 41 leaves:
# Student model score: 0.9854926208948258
# Student model 1-47 fidelity: 0.9854926208948258
# ########## Inner-loop Iteration 48/50 ##########
# Sampling 2763 points from training dataset with (90454, 90454) entries
# Student model 1-48 trained with depth 11 and 45 leaves:
# Student model score: 0.9903039801635107
# Student model 1-48 fidelity: 0.9903039801635107
# ########## Inner-loop Iteration 49/50 ##########
# Sampling 2763 points from training dataset with (91283, 91283) entries
# Student model 1-49 trained with depth 12 and 48 leaves:
# Student model score: 0.9915553052561422
# Student model 1-49 fidelity: 0.9915553052561422
# ########## Outer-loop Iteration 2/10 ##########
# Initializing Trustee inner-loop with 10 iterations
# ########## Inner-loop Iteration 0/50 ##########
# Sampling 2763 points from training dataset with (92112, 92112) entries
# Student model 2-0 trained with depth 11 and 39 leaves:
# Student model score: 0.991498893230025
# Student model 2-0 fidelity: 0.991498893230025
# ########## Inner-loop Iteration 1/50 ##########
# Sampling 2763 points from training dataset with (92941, 92941) entries
# Student model 2-1 trained with depth 15 and 46 leaves:
# Student model score: 0.9891419664959593
# Student model 2-1 fidelity: 0.9891419664959593
# ########## Inner-loop Iteration 2/50 ##########
# Sampling 2763 points from training dataset with (93770, 93770) entries
# Student model 2-2 trained with depth 12 and 45 leaves:
# Student model score: 0.9951681529404908
# Student model 2-2 fidelity: 0.9951681529404908
# ########## Inner-loop Iteration 3/50 ##########
# Sampling 2763 points from training dataset with (94599, 94599) entries
# Student model 2-3 trained with depth 11 and 40 leaves:
# Student model score: 0.9939500091224229
# Student model 2-3 fidelity: 0.9939500091224229
# ########## Inner-loop Iteration 4/50 ##########
# Sampling 2763 points from training dataset with (95428, 95428) entries
# Student model 2-4 trained with depth 10 and 50 leaves:
# Student model score: 0.9891435464414958
# Student model 2-4 fidelity: 0.9891435464414958
# ########## Inner-loop Iteration 5/50 ##########
# Sampling 2763 points from training dataset with (96257, 96257) entries
# Student model 2-5 trained with depth 10 and 40 leaves:
# Student model score: 0.990293762952382
# Student model 2-5 fidelity: 0.990293762952382
# ########## Inner-loop Iteration 6/50 ##########
# Sampling 2763 points from training dataset with (97086, 97086) entries
# Student model 2-6 trained with depth 9 and 43 leaves:
# Student model score: 0.9818880950820389
# Student model 2-6 fidelity: 0.9818880950820389
# ########## Inner-loop Iteration 7/50 ##########
# Sampling 2763 points from training dataset with (97915, 97915) entries
# Student model 2-7 trained with depth 10 and 40 leaves:
# Student model score: 0.9843176344758842
# Student model 2-7 fidelity: 0.9843176344758842
# ########## Inner-loop Iteration 8/50 ##########
# Sampling 2763 points from training dataset with (98744, 98744) entries
# Student model 2-8 trained with depth 11 and 52 leaves:
# Student model score: 0.9758489290791712
# Student model 2-8 fidelity: 0.9758489290791712
# ########## Inner-loop Iteration 9/50 ##########
# Sampling 2763 points from training dataset with (99573, 99573) entries
# Student model 2-9 trained with depth 11 and 47 leaves:
# Student model score: 0.983096811026833
# Student model 2-9 fidelity: 0.983096811026833
# ########## Inner-loop Iteration 10/50 ##########
# Sampling 2763 points from training dataset with (100402, 100402) entries
# Student model 2-10 trained with depth 10 and 51 leaves:
# Student model score: 0.9903494679984168
# Student model 2-10 fidelity: 0.9903494679984168
# ########## Inner-loop Iteration 11/50 ##########
# Sampling 2763 points from training dataset with (101231, 101231) entries
# Student model 2-11 trained with depth 11 and 46 leaves:
# Student model score: 0.9879244645395856
# Student model 2-11 fidelity: 0.9879244645395856
# ########## Inner-loop Iteration 12/50 ##########
# Sampling 2763 points from training dataset with (102060, 102060) entries
# Student model 2-12 trained with depth 11 and 53 leaves:
# Student model score: 0.9903159862157584
# Student model 2-12 fidelity: 0.9903159862157584
# ########## Inner-loop Iteration 13/50 ##########
# Sampling 2763 points from training dataset with (102889, 102889) entries
# Student model 2-13 trained with depth 10 and 36 leaves:
# Student model score: 0.9855044588214723
# Student model 2-13 fidelity: 0.9855044588214723
# ########## Inner-loop Iteration 14/50 ##########
# Sampling 2763 points from training dataset with (103718, 103718) entries
# Student model 2-14 trained with depth 9 and 41 leaves:
# Student model score: 0.9915227372662105
# Student model 2-14 fidelity: 0.9915227372662105
# ########## Inner-loop Iteration 15/50 ##########
# Sampling 2763 points from training dataset with (104547, 104547) entries
# Student model 2-15 trained with depth 11 and 38 leaves:
# Student model score: 0.985523022294662
# Student model 2-15 fidelity: 0.985523022294662
# ########## Inner-loop Iteration 16/50 ##########
# Sampling 2763 points from training dataset with (105376, 105376) entries
# Student model 2-16 trained with depth 8 and 33 leaves:
# Student model score: 0.9891372238989811
# Student model 2-16 fidelity: 0.9891372238989811
# ########## Inner-loop Iteration 17/50 ##########
# Sampling 2763 points from training dataset with (106205, 106205) entries
# Student model 2-17 trained with depth 12 and 51 leaves:
# Student model score: 0.992761511147331
# Student model 2-17 fidelity: 0.992761511147331
# ########## Inner-loop Iteration 18/50 ##########
# Sampling 2763 points from training dataset with (107034, 107034) entries
# Student model 2-18 trained with depth 13 and 50 leaves:
# Student model score: 0.985513577744382
# Student model 2-18 fidelity: 0.985513577744382
# ########## Inner-loop Iteration 19/50 ##########
# Sampling 2763 points from training dataset with (107863, 107863) entries
# Student model 2-19 trained with depth 13 and 45 leaves:
# Student model score: 0.978275681341719
# Student model 2-19 fidelity: 0.978275681341719
# ########## Inner-loop Iteration 20/50 ##########
# Sampling 2763 points from training dataset with (108692, 108692) entries
# Student model 2-20 trained with depth 10 and 45 leaves:
# Student model score: 0.9927546787237514
# Student model 2-20 fidelity: 0.9927546787237514
# ########## Inner-loop Iteration 21/50 ##########
# Sampling 2763 points from training dataset with (109521, 109521) entries
# Student model 2-21 trained with depth 14 and 49 leaves:
# Student model score: 0.9903496926802011
# Student model 2-21 fidelity: 0.9903496926802011
# ########## Inner-loop Iteration 22/50 ##########
# Sampling 2763 points from training dataset with (110350, 110350) entries
# Student model 2-22 trained with depth 9 and 45 leaves:
# Student model score: 0.9891293103573879
# Student model 2-22 fidelity: 0.9891293103573879
# ########## Inner-loop Iteration 23/50 ##########
# Sampling 2763 points from training dataset with (111179, 111179) entries
# Student model 2-23 trained with depth 9 and 36 leaves:
# Student model score: 0.9915252628366054
# Student model 2-23 fidelity: 0.9915252628366054
# ########## Inner-loop Iteration 24/50 ##########
# Sampling 2763 points from training dataset with (112008, 112008) entries
# Student model 2-24 trained with depth 11 and 45 leaves:
# Student model score: 0.9890784533298201
# Student model 2-24 fidelity: 0.9890784533298201
# ########## Inner-loop Iteration 25/50 ##########
# Sampling 2763 points from training dataset with (112837, 112837) entries
# Student model 2-25 trained with depth 9 and 38 leaves:
# Student model score: 0.9855154338963308
# Student model 2-25 fidelity: 0.9855154338963308
# ########## Inner-loop Iteration 26/50 ##########
# Sampling 2763 points from training dataset with (113666, 113666) entries
# Student model 2-26 trained with depth 10 and 41 leaves:
# Student model score: 0.9831033077102259
# Student model 2-26 fidelity: 0.9831033077102259
# ########## Inner-loop Iteration 27/50 ##########
# Sampling 2763 points from training dataset with (114495, 114495) entries
# Student model 2-27 trained with depth 13 and 45 leaves:
# Student model score: 0.9867309239752807
# Student model 2-27 fidelity: 0.9867309239752807
# ########## Inner-loop Iteration 28/50 ##########
# Sampling 2763 points from training dataset with (115324, 115324) entries
# Student model 2-28 trained with depth 11 and 44 leaves:
# Student model score: 0.983108029435052
# Student model 2-28 fidelity: 0.983108029435052
# ########## Inner-loop Iteration 29/50 ##########
# Sampling 2763 points from training dataset with (116153, 116153) entries
# Student model 2-29 trained with depth 11 and 42 leaves:
# Student model score: 0.9951565786398693
# Student model 2-29 fidelity: 0.9951565786398693
# ########## Inner-loop Iteration 30/50 ##########
# Sampling 2763 points from training dataset with (116982, 116982) entries
# Student model 2-30 trained with depth 12 and 44 leaves:
# Student model score: 0.9879351496099663
# Student model 2-30 fidelity: 0.9879351496099663
# ########## Inner-loop Iteration 31/50 ##########
# Sampling 2763 points from training dataset with (117811, 117811) entries
# Student model 2-31 trained with depth 14 and 46 leaves:
# Student model score: 0.9855017547132414
# Student model 2-31 fidelity: 0.9855017547132414
# ########## Inner-loop Iteration 32/50 ##########
# Sampling 2763 points from training dataset with (118640, 118640) entries
# Student model 2-32 trained with depth 13 and 46 leaves:
# Student model score: 0.9756534508076358
# Student model 2-32 fidelity: 0.9756534508076358
# ########## Inner-loop Iteration 33/50 ##########
# Sampling 2763 points from training dataset with (119469, 119469) entries
# Student model 2-33 trained with depth 10 and 47 leaves:
# Student model score: 0.984318364698059
# Student model 2-33 fidelity: 0.984318364698059
# ########## Inner-loop Iteration 34/50 ##########
# Sampling 2763 points from training dataset with (120298, 120298) entries
# Student model 2-34 trained with depth 9 and 39 leaves:
# Student model score: 0.9903159862157584
# Student model 2-34 fidelity: 0.9903159862157584
# ########## Inner-loop Iteration 35/50 ##########
# Sampling 2763 points from training dataset with (121127, 121127) entries
# Student model 2-35 trained with depth 12 and 37 leaves:
# Student model score: 0.9830853804987816
# Student model 2-35 fidelity: 0.9830853804987816
# ########## Inner-loop Iteration 36/50 ##########
# Sampling 2763 points from training dataset with (121956, 121956) entries
# Student model 2-36 trained with depth 11 and 40 leaves:
# Student model score: 0.9939684964895049
# Student model 2-36 fidelity: 0.9939684964895049
# ########## Inner-loop Iteration 37/50 ##########
# Sampling 2763 points from training dataset with (122785, 122785) entries
# Student model 2-37 trained with depth 12 and 41 leaves:
# Student model score: 0.9891100164203612
# Student model 2-37 fidelity: 0.9891100164203612
# ########## Inner-loop Iteration 38/50 ##########
# Sampling 2763 points from training dataset with (123614, 123614) entries
# Student model 2-38 trained with depth 9 and 38 leaves:
# Student model score: 0.9794184954603273
# Student model 2-38 fidelity: 0.9794184954603273
# ########## Inner-loop Iteration 39/50 ##########
# Sampling 2763 points from training dataset with (124443, 124443) entries
# Student model 2-39 trained with depth 10 and 38 leaves:
# Student model score: 0.9891070273616405
# Student model 2-39 fidelity: 0.9891070273616405
# ########## Inner-loop Iteration 40/50 ##########
# Sampling 2763 points from training dataset with (125272, 125272) entries
# Student model 2-40 trained with depth 12 and 55 leaves:
# Student model score: 0.9842516348226353
# Student model 2-40 fidelity: 0.9842516348226353
# ########## Inner-loop Iteration 41/50 ##########
# Sampling 2763 points from training dataset with (126101, 126101) entries
# Student model 2-41 trained with depth 10 and 47 leaves:
# Student model score: 0.9867030622764463
# Student model 2-41 fidelity: 0.9867030622764463
# ########## Inner-loop Iteration 42/50 ##########
# Sampling 2763 points from training dataset with (126930, 126930) entries
# Student model 2-42 trained with depth 11 and 38 leaves:
# Student model score: 0.9951743407648874
# Student model 2-42 fidelity: 0.9951743407648874
# ########## Inner-loop Iteration 43/50 ##########
# Sampling 2763 points from training dataset with (127759, 127759) entries
# Student model 2-43 trained with depth 11 and 38 leaves:
# Student model score: 0.9867290701617282
# Student model 2-43 fidelity: 0.9867290701617282
# ########## Inner-loop Iteration 44/50 ##########
# Sampling 2763 points from training dataset with (128588, 128588) entries
# Student model 2-44 trained with depth 14 and 43 leaves:
# Student model score: 0.9877835282467227
# Student model 2-44 fidelity: 0.9877835282467227
# ########## Inner-loop Iteration 45/50 ##########
# Sampling 2763 points from training dataset with (129417, 129417) entries
# Student model 2-45 trained with depth 12 and 48 leaves:
# Student model score: 0.9854052721767095
# Student model 2-45 fidelity: 0.9854052721767095
# ########## Inner-loop Iteration 46/50 ##########
# Sampling 2763 points from training dataset with (130246, 130246) entries
# Student model 2-46 trained with depth 12 and 43 leaves:
# Student model score: 0.980682069744952
# Student model 2-46 fidelity: 0.980682069744952
# ########## Inner-loop Iteration 47/50 ##########
# Sampling 2763 points from training dataset with (131075, 131075) entries
# Student model 2-47 trained with depth 12 and 48 leaves:
# Student model score: 0.9878672036904775
# Student model 2-47 fidelity: 0.9878672036904775
# ########## Inner-loop Iteration 48/50 ##########
# Sampling 2763 points from training dataset with (131904, 131904) entries
# Student model 2-48 trained with depth 10 and 42 leaves:
# Student model score: 0.9818973762477854
# Student model 2-48 fidelity: 0.9818973762477854
# ########## Inner-loop Iteration 49/50 ##########
# Sampling 2763 points from training dataset with (132733, 132733) entries
# Student model 2-49 trained with depth 9 and 29 leaves:
# Student model score: 0.9891384257486713
# Student model 2-49 fidelity: 0.9891384257486713
# ########## Outer-loop Iteration 3/10 ##########
# Initializing Trustee inner-loop with 10 iterations
# ########## Inner-loop Iteration 0/50 ##########
# Sampling 2763 points from training dataset with (133562, 133562) entries
# Student model 3-0 trained with depth 12 and 46 leaves:
# Student model score: 0.9879309340787328
# Student model 3-0 fidelity: 0.9879309340787328
# ########## Inner-loop Iteration 1/50 ##########
# Sampling 2763 points from training dataset with (134391, 134391) entries
# Student model 3-1 trained with depth 10 and 44 leaves:
# Student model score: 0.9890515286918624
# Student model 3-1 fidelity: 0.9890515286918624
# ########## Inner-loop Iteration 2/50 ##########
# Sampling 2763 points from training dataset with (135220, 135220) entries
# Student model 3-2 trained with depth 9 and 31 leaves:
# Student model score: 0.9915556493331683
# Student model 3-2 fidelity: 0.9915556493331683
# ########## Inner-loop Iteration 3/50 ##########
# Sampling 2763 points from training dataset with (136049, 136049) entries
# Student model 3-3 trained with depth 12 and 48 leaves:
# Student model score: 0.990341034872476
# Student model 3-3 fidelity: 0.990341034872476
# ########## Inner-loop Iteration 4/50 ##########
# Sampling 2763 points from training dataset with (136878, 136878) entries
# Student model 3-4 trained with depth 11 and 39 leaves:
# Student model score: 0.9879224941724942
# Student model 3-4 fidelity: 0.9879224941724942
# ########## Inner-loop Iteration 5/50 ##########
# Sampling 2763 points from training dataset with (137707, 137707) entries
# Student model 3-5 trained with depth 14 and 36 leaves:
# Student model score: 0.9855171208944795
# Student model 3-5 fidelity: 0.9855171208944795
# ########## Inner-loop Iteration 6/50 ##########
# Sampling 2763 points from training dataset with (138536, 138536) entries
# Student model 3-6 trained with depth 14 and 51 leaves:
# Student model score: 0.9855186388568633
# Student model 3-6 fidelity: 0.9855186388568633
# ########## Inner-loop Iteration 7/50 ##########
# Sampling 2763 points from training dataset with (139365, 139365) entries
# Student model 3-7 trained with depth 8 and 28 leaves:
# Student model score: 0.98542374868128
# Student model 3-7 fidelity: 0.98542374868128
# ########## Inner-loop Iteration 8/50 ##########
# Sampling 2763 points from training dataset with (140194, 140194) entries
# Student model 3-8 trained with depth 11 and 39 leaves:
# Student model score: 0.9818880950820388
# Student model 3-8 fidelity: 0.9818880950820388
# ########## Inner-loop Iteration 9/50 ##########
# Sampling 2763 points from training dataset with (141023, 141023) entries
# Student model 3-9 trained with depth 11 and 44 leaves:
# Student model score: 0.9915418643462545
# Student model 3-9 fidelity: 0.9915418643462545
# ########## Inner-loop Iteration 10/50 ##########
# Sampling 2763 points from training dataset with (141852, 141852) entries
# Student model 3-10 trained with depth 10 and 51 leaves:
# Student model score: 0.9891128767483091
# Student model 3-10 fidelity: 0.9891128767483091
# ########## Inner-loop Iteration 11/50 ##########
# Sampling 2763 points from training dataset with (142681, 142681) entries
# Student model 3-11 trained with depth 9 and 39 leaves:
# Student model score: 0.9831050786663406
# Student model 3-11 fidelity: 0.9831050786663406
# ########## Inner-loop Iteration 12/50 ##########
# Sampling 2763 points from training dataset with (143510, 143510) entries
# Student model 3-12 trained with depth 10 and 44 leaves:
# Student model score: 0.9879321990473862
# Student model 3-12 fidelity: 0.9879321990473862
# ########## Inner-loop Iteration 13/50 ##########
# Sampling 2763 points from training dataset with (144339, 144339) entries
# Student model 3-13 trained with depth 11 and 41 leaves:
# Student model score: 0.9939277808785894
# Student model 3-13 fidelity: 0.9939277808785894
# ########## Inner-loop Iteration 14/50 ##########
# Sampling 2763 points from training dataset with (145168, 145168) entries
# Student model 3-14 trained with depth 9 and 34 leaves:
# Student model score: 0.9915490086140986
# Student model 3-14 fidelity: 0.9915490086140986
# ########## Inner-loop Iteration 15/50 ##########
# Sampling 2763 points from training dataset with (145997, 145997) entries
# Student model 3-15 trained with depth 13 and 49 leaves:
# Student model score: 0.9855242019976252
# Student model 3-15 fidelity: 0.9855242019976252
# ########## Inner-loop Iteration 16/50 ##########
# Sampling 2763 points from training dataset with (146826, 146826) entries
# Student model 3-16 trained with depth 11 and 43 leaves:
# Student model score: 0.9793544549872035
# Student model 3-16 fidelity: 0.9793544549872035
# ########## Inner-loop Iteration 17/50 ##########
# Sampling 2763 points from training dataset with (147655, 147655) entries
# Student model 3-17 trained with depth 11 and 41 leaves:
# Student model score: 0.9867000368997769
# Student model 3-17 fidelity: 0.9867000368997769
# ########## Inner-loop Iteration 18/50 ##########
# Sampling 2763 points from training dataset with (148484, 148484) entries
# Student model 3-18 trained with depth 9 and 31 leaves:
# Student model score: 0.9879372562714627
# Student model 3-18 fidelity: 0.9879372562714627
# ########## Inner-loop Iteration 19/50 ##########
# Sampling 2763 points from training dataset with (149313, 149313) entries
# Student model 3-19 trained with depth 11 and 46 leaves:
# Student model score: 0.9867198706792978
# Student model 3-19 fidelity: 0.9867198706792978
# ########## Inner-loop Iteration 20/50 ##########
# Sampling 2763 points from training dataset with (150142, 150142) entries
# Student model 3-20 trained with depth 14 and 43 leaves:
# Student model score: 0.9891395008624643
# Student model 3-20 fidelity: 0.9891395008624643
# ########## Inner-loop Iteration 21/50 ##########
# Sampling 2763 points from training dataset with (150971, 150971) entries
# Student model 3-21 trained with depth 9 and 46 leaves:
# Student model score: 0.9902901249751104
# Student model 3-21 fidelity: 0.9902901249751104
# ########## Inner-loop Iteration 22/50 ##########
# Sampling 2763 points from training dataset with (151800, 151800) entries
# Student model 3-22 trained with depth 8 and 31 leaves:
# Student model score: 0.9842781012346147
# Student model 3-22 fidelity: 0.9842781012346147
# ########## Inner-loop Iteration 23/50 ##########
# Sampling 2763 points from training dataset with (152629, 152629) entries
# Student model 3-23 trained with depth 9 and 34 leaves:
# Student model score: 0.9867306922769108
# Student model 3-23 fidelity: 0.9867306922769108
# ########## Inner-loop Iteration 24/50 ##########
# Sampling 2763 points from training dataset with (153458, 153458) entries
# Student model 3-24 trained with depth 11 and 46 leaves:
# Student model score: 0.9842700237182995
# Student model 3-24 fidelity: 0.9842700237182995
# ########## Inner-loop Iteration 25/50 ##########
# Sampling 2763 points from training dataset with (154287, 154287) entries
# Student model 3-25 trained with depth 10 and 34 leaves:
# Student model score: 0.9891230346456348
# Student model 3-25 fidelity: 0.9891230346456348
# ########## Inner-loop Iteration 26/50 ##########
# Sampling 2763 points from training dataset with (155116, 155116) entries
# Student model 3-26 trained with depth 10 and 44 leaves:
# Student model score: 0.984303015737767
# Student model 3-26 fidelity: 0.984303015737767
# ########## Inner-loop Iteration 27/50 ##########
# Sampling 2763 points from training dataset with (155945, 155945) entries
# Student model 3-27 trained with depth 11 and 43 leaves:
# Student model score: 0.9867260566096785
# Student model 3-27 fidelity: 0.9867260566096785
# ########## Inner-loop Iteration 28/50 ##########
# Sampling 2763 points from training dataset with (156774, 156774) entries
# Student model 3-28 trained with depth 9 and 43 leaves:
# Student model score: 0.9903345031421609
# Student model 3-28 fidelity: 0.9903345031421609
# ########## Inner-loop Iteration 29/50 ##########
# Sampling 2763 points from training dataset with (157603, 157603) entries
# Student model 3-29 trained with depth 11 and 46 leaves:
# Student model score: 0.9879364136951536
# ...
# Student model score: 0.9842413182487494
# Student model 8-47 fidelity: 0.9842413182487494
# ########## Inner-loop Iteration 48/50 ##########
# Sampling 2763 points from training dataset with (380604, 380604) entries
# Student model 8-48 trained with depth 14 and 51 leaves:
# Student model score: 0.9769434014740648
# Student model 8-48 fidelity: 0.9769434014740648
# ########## Inner-loop Iteration 49/50 ##########
# Sampling 2763 points from training dataset with (381433, 381433) entries
# Student model 8-49 trained with depth 8 and 38 leaves:
# Student model score: 0.9843074042201243
# Student model 8-49 fidelity: 0.9843074042201243
# ########## Outer-loop Iteration 9/10 ##########
# Initializing Trustee inner-loop with 10 iterations
# ########## Inner-loop Iteration 0/50 ##########
# Sampling 2763 points from training dataset with (382262, 382262) entries
# Student model 9-0 trained with depth 10 and 40 leaves:
# Student model score: 0.9903496926802011
# Student model 9-0 fidelity: 0.9903496926802011
# ########## Inner-loop Iteration 1/50 ##########
# Sampling 2763 points from training dataset with (383091, 383091) entries
# Student model 9-1 trained with depth 11 and 45 leaves:
# Student model score: 0.9770037244301302
# Student model 9-1 fidelity: 0.9770037244301302
# ########## Inner-loop Iteration 2/50 ##########
# Sampling 2763 points from training dataset with (383920, 383920) entries
# Student model 9-2 trained with depth 12 and 36 leaves:
# Student model score: 0.991514555980096
# Student model 9-2 fidelity: 0.991514555980096
# ########## Inner-loop Iteration 3/50 ##########
# Sampling 2763 points from training dataset with (384749, 384749) entries
# Student model 9-3 trained with depth 11 and 40 leaves:
# Student model score: 0.9770615948096961
# Student model 9-3 fidelity: 0.9770615948096961
# ########## Inner-loop Iteration 4/50 ##########
# Sampling 2763 points from training dataset with (385578, 385578) entries
# Student model 9-4 trained with depth 12 and 42 leaves:
# Student model score: 0.9867030622764463
# Student model 9-4 fidelity: 0.9867030622764463
# ########## Inner-loop Iteration 5/50 ##########
# Sampling 2763 points from training dataset with (386407, 386407) entries
# Student model 9-5 trained with depth 13 and 48 leaves:
# Student model score: 0.9879358519122183
# Student model 9-5 fidelity: 0.9879358519122183
# ########## Inner-loop Iteration 6/50 ##########
# Sampling 2763 points from training dataset with (387236, 387236) entries
# Student model 9-6 trained with depth 11 and 39 leaves:
# Student model score: 0.9902863704536933
# Student model 9-6 fidelity: 0.9902863704536933
# ########## Inner-loop Iteration 7/50 ##########
# Sampling 2763 points from training dataset with (388065, 388065) entries
# Student model 9-7 trained with depth 12 and 45 leaves:
# Student model score: 0.9890937794636788
# Student model 9-7 fidelity: 0.9890937794636788
# ########## Inner-loop Iteration 8/50 ##########
# Sampling 2763 points from training dataset with (388894, 388894) entries
# Student model 9-8 trained with depth 13 and 50 leaves:
# Student model score: 0.983103307710226
# Student model 9-8 fidelity: 0.983103307710226
# ########## Inner-loop Iteration 9/50 ##########
# Sampling 2763 points from training dataset with (389723, 389723) entries
# Student model 9-9 trained with depth 8 and 36 leaves:
# Student model score: 0.9891311473260525
# Student model 9-9 fidelity: 0.9891311473260525
# ########## Inner-loop Iteration 10/50 ##########
# Sampling 2763 points from training dataset with (390552, 390552) entries
# Student model 9-10 trained with depth 12 and 40 leaves:
# Student model score: 0.9939500091224229
# Student model 9-10 fidelity: 0.9939500091224229
# ########## Inner-loop Iteration 11/50 ##########
# Sampling 2763 points from training dataset with (391381, 391381) entries
# Student model 9-11 trained with depth 11 and 46 leaves:
# Student model score: 0.9854926208948259
# Student model 9-11 fidelity: 0.9854926208948259
# ########## Inner-loop Iteration 12/50 ##########
# Sampling 2763 points from training dataset with (392210, 392210) entries
# Student model 9-12 trained with depth 11 and 44 leaves:
# Student model score: 0.9915434913445746
# Student model 9-12 fidelity: 0.9915434913445746
# ########## Inner-loop Iteration 13/50 ##########
# Sampling 2763 points from training dataset with (393039, 393039) entries
# Student model 9-13 trained with depth 10 and 48 leaves:
# Student model score: 0.9914508004838114
# Student model 9-13 fidelity: 0.9914508004838114
# ########## Inner-loop Iteration 14/50 ##########
# Sampling 2763 points from training dataset with (393868, 393868) entries
# Student model 9-14 trained with depth 11 and 43 leaves:
# Student model score: 0.9927618482170921
# Student model 9-14 fidelity: 0.9927618482170921
# ########## Inner-loop Iteration 15/50 ##########
# Sampling 2763 points from training dataset with (394697, 394697) entries
# Student model 9-15 trained with depth 11 and 62 leaves:
# Student model score: 0.9866935160257111
# Student model 9-15 fidelity: 0.9866935160257111
# ########## Inner-loop Iteration 16/50 ##########
# Sampling 2763 points from training dataset with (395526, 395526) entries
# Student model 9-16 trained with depth 12 and 48 leaves:
# Student model score: 0.9866244233716897
# Student model 9-16 fidelity: 0.9866244233716897
# ########## Inner-loop Iteration 17/50 ##########
# Sampling 2763 points from training dataset with (396355, 396355) entries
# Student model 9-17 trained with depth 12 and 51 leaves:
# Student model score: 0.9806820697449521
# Student model 9-17 fidelity: 0.9806820697449521
# ########## Inner-loop Iteration 18/50 ##########
# Sampling 2763 points from training dataset with (397184, 397184) entries
# Student model 9-18 trained with depth 10 and 45 leaves:
# Student model score: 0.9843110594147474
# Student model 9-18 fidelity: 0.9843110594147474
# ########## Inner-loop Iteration 19/50 ##########
# Sampling 2763 points from training dataset with (398013, 398013) entries
# Student model 9-19 trained with depth 12 and 48 leaves:
# Student model score: 0.9879343067393227
# Student model 9-19 fidelity: 0.9879343067393227
# ########## Inner-loop Iteration 20/50 ##########
# Sampling 2763 points from training dataset with (398842, 398842) entries
# Student model 9-20 trained with depth 10 and 38 leaves:
# Student model score: 0.9782566882322083
# Student model 9-20 fidelity: 0.9782566882322083
# ########## Inner-loop Iteration 21/50 ##########
# Sampling 2763 points from training dataset with (399671, 399671) entries
# Student model 9-21 trained with depth 14 and 46 leaves:
# Student model score: 0.98429505535421
# Student model 9-21 fidelity: 0.98429505535421
# ########## Inner-loop Iteration 22/50 ##########
# Sampling 2763 points from training dataset with (400500, 400500) entries
# Student model 9-22 trained with depth 10 and 38 leaves:
# Student model score: 0.9842657061890364
# Student model 9-22 fidelity: 0.9842657061890364
# ########## Inner-loop Iteration 23/50 ##########
# Sampling 2763 points from training dataset with (401329, 401329) entries
# Student model 9-23 trained with depth 10 and 36 leaves:
# Student model score: 0.9939515981935052
# Student model 9-23 fidelity: 0.9939515981935052
# ########## Inner-loop Iteration 24/50 ##########
# Sampling 2763 points from training dataset with (402158, 402158) entries
# Student model 9-24 trained with depth 12 and 41 leaves:
# Student model score: 0.9879105174123548
# Student model 9-24 fidelity: 0.9879105174123548
# ########## Inner-loop Iteration 25/50 ##########
# Sampling 2763 points from training dataset with (402987, 402987) entries
# Student model 9-25 trained with depth 11 and 41 leaves:
# Student model score: 0.9903237855125243
# Student model 9-25 fidelity: 0.9903237855125243
# ########## Inner-loop Iteration 26/50 ##########
# Sampling 2763 points from training dataset with (403816, 403816) entries
# Student model 9-26 trained with depth 11 and 48 leaves:
# Student model score: 0.9673468256411228
# Student model 9-26 fidelity: 0.9673468256411228
# ########## Inner-loop Iteration 27/50 ##########
# Sampling 2763 points from training dataset with (404645, 404645) entries
# Student model 9-27 trained with depth 10 and 42 leaves:
# Student model score: 0.9903395716316685
# Student model 9-27 fidelity: 0.9903395716316685
# ########## Inner-loop Iteration 28/50 ##########
# Sampling 2763 points from training dataset with (405474, 405474) entries
# Student model 9-28 trained with depth 11 and 46 leaves:
# Student model score: 0.9842657061890364
# Student model 9-28 fidelity: 0.9842657061890364
# ########## Inner-loop Iteration 29/50 ##########
# Sampling 2763 points from training dataset with (406303, 406303) entries
# Student model 9-29 trained with depth 12 and 48 leaves:
# Student model score: 0.9806568278597678
# Student model 9-29 fidelity: 0.9806568278597678
# ########## Inner-loop Iteration 30/50 ##########
# Sampling 2763 points from training dataset with (407132, 407132) entries
# Student model 9-30 trained with depth 16 and 47 leaves:
# Student model score: 0.9903457592379089
# Student model 9-30 fidelity: 0.9903457592379089
# ########## Inner-loop Iteration 31/50 ##########
# Sampling 2763 points from training dataset with (407961, 407961) entries
# Student model 9-31 trained with depth 10 and 43 leaves:
# Student model score: 0.9879364136951536
# Student model 9-31 fidelity: 0.9879364136951536
# ########## Inner-loop Iteration 32/50 ##########
# Sampling 2763 points from training dataset with (408790, 408790) entries
# Student model 9-32 trained with depth 10 and 48 leaves:
# Student model score: 0.9806319724315169
# Student model 9-32 fidelity: 0.9806319724315169
# ########## Inner-loop Iteration 33/50 ##########
# Sampling 2763 points from training dataset with (409619, 409619) entries
# Student model 9-33 trained with depth 12 and 42 leaves:
# Student model score: 0.9867310012062726
# Student model 9-33 fidelity: 0.9867310012062726
# ########## Inner-loop Iteration 34/50 ##########
# Sampling 2763 points from training dataset with (410448, 410448) entries
# Student model 9-34 trained with depth 12 and 45 leaves:
# Student model score: 0.9879279814536517
# Student model 9-34 fidelity: 0.9879279814536517
# ########## Inner-loop Iteration 35/50 ##########
# Sampling 2763 points from training dataset with (411277, 411277) entries
# Student model 9-35 trained with depth 13 and 52 leaves:
# Student model score: 0.9842700237182996
# Student model 9-35 fidelity: 0.9842700237182996
# ########## Inner-loop Iteration 36/50 ##########
# Sampling 2763 points from training dataset with (412106, 412106) entries
# Student model 9-36 trained with depth 9 and 34 leaves:
# Student model score: 0.9843169954756925
# Student model 9-36 fidelity: 0.9843169954756925
# ########## Inner-loop Iteration 37/50 ##########
# Sampling 2763 points from training dataset with (412935, 412935) entries
# Student model 9-37 trained with depth 12 and 35 leaves:
# Student model score: 0.9903447472629863
# Student model 9-37 fidelity: 0.9903447472629863
# ########## Inner-loop Iteration 38/50 ##########
# Sampling 2763 points from training dataset with (413764, 413764) entries
# Student model 9-38 trained with depth 9 and 35 leaves:
# Student model score: 0.9878626562188879
# Student model 9-38 fidelity: 0.9878626562188879
# ########## Inner-loop Iteration 39/50 ##########
# Sampling 2763 points from training dataset with (414593, 414593) entries
# Student model 9-39 trained with depth 11 and 40 leaves:
# Student model score: 0.9927479179788647
# Student model 9-39 fidelity: 0.9927479179788647
# ########## Inner-loop Iteration 40/50 ##########
# Sampling 2763 points from training dataset with (415422, 415422) entries
# Student model 9-40 trained with depth 12 and 43 leaves:
# Student model score: 0.9891070273616407
# Student model 9-40 fidelity: 0.9891070273616407
# ########## Inner-loop Iteration 41/50 ##########
# Sampling 2763 points from training dataset with (416251, 416251) entries
# Student model 9-41 trained with depth 12 and 51 leaves:
# Student model score: 0.991540138057716
# Student model 9-41 fidelity: 0.991540138057716
# ########## Inner-loop Iteration 42/50 ##########
# Sampling 2763 points from training dataset with (417080, 417080) entries
# Student model 9-42 trained with depth 12 and 35 leaves:
# Student model score: 0.9927557761543571
# Student model 9-42 fidelity: 0.9927557761543571
# ########## Inner-loop Iteration 43/50 ##########
# Sampling 2763 points from training dataset with (417909, 417909) entries
# Student model 9-43 trained with depth 12 and 43 leaves:
# Student model score: 0.9818041343465073
# Student model 9-43 fidelity: 0.9818041343465073
# ########## Inner-loop Iteration 44/50 ##########
# Sampling 2763 points from training dataset with (418738, 418738) entries
# Student model 9-44 trained with depth 11 and 42 leaves:
# Student model score: 0.9854697359196074
# Student model 9-44 fidelity: 0.9854697359196074
# ########## Inner-loop Iteration 45/50 ##########
# Sampling 2763 points from training dataset with (419567, 419567) entries
# Student model 9-45 trained with depth 10 and 45 leaves:
# Student model score: 0.9878579630671166
# Student model 9-45 fidelity: 0.9878579630671166
# ########## Inner-loop Iteration 46/50 ##########
# Sampling 2763 points from training dataset with (420396, 420396) entries
# Student model 9-46 trained with depth 11 and 39 leaves:
# Student model score: 0.9927463104474129
# Student model 9-46 fidelity: 0.9927463104474129
# ########## Inner-loop Iteration 47/50 ##########
# Sampling 2763 points from training dataset with (421225, 421225) entries
# Student model 9-47 trained with depth 11 and 41 leaves:
# Student model score: 0.9866935160257112
# Student model 9-47 fidelity: 0.9866935160257112
# ########## Inner-loop Iteration 48/50 ##########
# Sampling 2763 points from training dataset with (422054, 422054) entries
# Student model 9-48 trained with depth 9 and 33 leaves:
# Student model score: 0.9902102031176192
# Student model 9-48 fidelity: 0.9902102031176192
# ########## Inner-loop Iteration 49/50 ##########
# Sampling 2763 points from training dataset with (422883, 422883) entries
# Student model 9-49 trained with depth 13 and 54 leaves:
# Student model score: 0.9879351496099662
# Student model 9-49 fidelity: 0.9879351496099662
# Model explanation training (agreement, fidelity): (0.9884014703002697, 0.995171811298777)
# Model Explanation size: 71
# Top-k Prunned Model explanation size: 21
# Model explanation global fidelity report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      1651
#            1       0.98      0.99      0.99      1640
#
#     accuracy                           0.99      3291
#    macro avg       0.99      0.99      0.99      3291
# weighted avg       0.99      0.99      0.99      3291
#
# Top-k Model explanation global fidelity report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1651
#            1       0.98      0.98      0.98      1640
#
#     accuracy                           0.98      3291
#    macro avg       0.98      0.98      0.98      3291
# weighted avg       0.98      0.98      0.98      3291
#
# Model explanation score report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      1662
#            1       0.96      0.98      0.97      1629
#
#     accuracy                           0.97      3291
#    macro avg       0.97      0.97      0.97      3291
# weighted avg       0.97      0.97      0.97      3291
#
# Top-k Model explanation score report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1662
#            1       0.97      0.97      0.97      1629
#
#     accuracy                           0.97      3291
#    macro avg       0.97      0.97      0.97      3291
# weighted avg       0.97      0.97      0.97      3291
# /home/emily_hu/venv/lib/python3.10/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /home/emily_hu/venv/lib/python3.10/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(

# %%
import pickle

with open('dot_data.pkl', 'wb') as f:  # open a text file
    pickle.dump(dot_data, f)
with open('pruned_dt.pkl', 'wb') as f:  # open a text file
    pickle.dump(pruned_dt, f)
with open('dt.pkl', 'wb') as f:
    pickle.dump(dt, f)
